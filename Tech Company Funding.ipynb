# %%
import pandas as pd
import numpy as np
# Out:
# C:\Anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('tech_fundings.csv')

# %%
df.dtypes
# Out:
# index                    int64
# Company                 object
# Website                 object
# Region                  object
# Vertical                object
# Funding Amount (USD)    object
# Funding Stage           object
# Funding Date            object
# dtype: object

# %%
df.head()
# Out:
#    index    Company                   Website          Region  \
# 0      1   Internxt     https://internxt.com/           Spain
# 1      2   Dockflow      https://dockflow.com         Belgium
# 2      3  api.video         https://api.video          France
# 3      4    Buck.ai          https://buck.ai/   United States
# 4      5  Prodsight  https://www.prodsight.ai  United Kingdom
#
#                   Vertical Funding Amount (USD) Funding Stage Funding Date
# 0               Blockchain               278940          Seed       Jan-20
# 1                Logistics               292244          Seed       Jan-20
# 2           Developer APIs               300000          Seed       Jan-20
# 3  Artificial Intelligence               300000          Seed       Jan-20
# 4  Artificial Intelligence               529013          Seed       Jan-20

# %%
df.isnull().sum()
# Out:
# index                    0
# Company                  0
# Website                  0
# Region                  12
# Vertical                 0
# Funding Amount (USD)     0
# Funding Stage            0
# Funding Date             0
# dtype: int64

# %%
region_isnull = df['Region'].isnull()  #boolean series

# %%
df[region_isnull]
# Out:
#       index             Company                            Website Region  \
# 853     854              Hedget            https://www.hedget.com/    NaN
# 2050   2051               MOUND  https://pancakebunny.finance/farm    NaN
# 2244   2245               Realm             https://www.realm.art/    NaN
# 2335   2336             ArDrive                https://ardrive.io/    NaN
# 3328   3329       Orca Creative               https://www.orca.so/    NaN
# 3333   3334       Grape Network            https://grapes.network/    NaN
# 3344   3345      Angle Protocol           https://www.angle.money/    NaN
# 3353   3354  Domination Finance        https://domination.finance/    NaN
# 3374   3375             Solcial                https://solcial.io/    NaN
# 3390   3391          Liveblocks              https://liveblocks.io    NaN
# 3398   3399            Talisman              https://talisman.xyz/    NaN
# 3453   3454            PrimeDAO          https://primedao.eth.link    NaN
#
# ...

# %%
#hapus kolom index dan website karena tidak digunakan
df.drop(columns=['index'], inplace=True)
df.drop(columns=['Website'], inplace=True)

# %%
df.head()
# Out:
#      Company          Region                 Vertical Funding Amount (USD)  \
# 0   Internxt           Spain               Blockchain               278940
# 1   Dockflow         Belgium                Logistics               292244
# 2  api.video          France           Developer APIs               300000
# 3    Buck.ai   United States  Artificial Intelligence               300000
# 4  Prodsight  United Kingdom  Artificial Intelligence               529013
#
#   Funding Stage Funding Date
# 0          Seed       Jan-20
# 1          Seed       Jan-20
# 2          Seed       Jan-20
# 3          Seed       Jan-20
# 4          Seed       Jan-20

# %%
df.size
# Out:
# 21450

# %%
#df['Region']=='United States' boolean series

# %%
df_US = df[df['Region']=='United States']

# %%
df_US.shape
# Out:
# (2034, 6)

# %%
df_US = df.query("Region == 'United States'")

# %%
df_US.shape
# Out:
# (2034, 6)

# %%
df_US.to_csv('Company Funding US.csv', index=False)

# %%
df_US.head(2034)
# Out:
#              Company         Region                 Vertical  \
# 3            Buck.ai  United States  Artificial Intelligence
# 6            Seatrec  United States        Marine Technology
# 7          BeeCanvas  United States             B2B Software
# 8        SmartKarrot  United States             B2B Software
# 10      Fundraise Up  United States             B2B Software
# ...              ...            ...                      ...
# 3559  Locus Robotics  United States                 Robotics
# 3560         Discord  United States           Social Network
# 3562           Qwilt  United States       Telecommunications
# 3569   SmarterTravel  United States                   Travel
# 3570         Headout  United States                   Travel
#
#      Funding Amount (USD) Funding Stage Funding Date
# 3                  300000          Seed       Jan-20
# 6                  970000          Seed       Jan-20
# 7                 1000000          Seed       Jan-20
# ...

# %%
df_US.query()
